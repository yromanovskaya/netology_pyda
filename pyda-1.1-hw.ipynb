# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, й проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
#решение 1.
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
len (long_phrase) > len (short_phrase)
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах. Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*"

# %%
#решение 2.
file_size_b = 50782119584372
file_size_mb = file_size_b / 1000000
print ('Объем файла равен ', file_size_mb, ' Mb')
# Out:
# Объем файла равен  50782119.584372  Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
#решение 3.
mounth = input ('Введите месяц: ')
date = input ('Введите число: ')
if mounth == 'март':
    if date < '22': 
        print ('Рыбы')
    else: print ('Овен')
elif mounth == 'апрель':
    if date < '21': 
        print ('Овен')
    else: print ('Телец')
elif mounth == 'май':
    if date < '21': 
        print ('Телец')
    else: print ('Близнецы')
elif mounth == 'июнь':
    if date < '22': 
        print ('Близнецы')
    else: print ('Рак')
elif mounth == 'июль':
    if date < '23': 
        print ('Рак')
    else: print ('Лев')
elif mounth == 'август':
    if date < '23': 
        print ('Лев')
    else: print ('Дева')
elif mounth == 'сентябрь':
    if date < '22': 
        print ('Дева')
    else: print ('Весы')
elif mounth == 'октябрь':
    if date < '24': 
        print ('Весы')
    else: print ('Скорпион')
elif mounth == 'ноябрь':
    if date < '22': 
        print ('Скорпион')
    else: print ('Стрелец')
elif mounth == 'декабрь':
    if date < '22': 
        print ('Стрелец')
    else: print ('Козерог')
elif mounth == 'январь':
    if date < '21': 
        print ('Козерог')
    else: print ('Водолей')
elif mounth == 'февраль':
    if date < '19': 
        print ('Водолей')
    else: print ('Рыбы')
else: print ('Проверьте написание месяца')
# Out:
# Введите месяц: июнь
# Введите число: 26
# Рак

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
#решение 4.
wage = input ('Введите заработанную плату в месяц: ')
mortgage = input ('Введите сколько процентов уходит на ипотеку: ')
spending = input ('Введите сколько процентов уходит на жизнь: ')
premium = input ('Введите количество премий за год: ')
mortgage_expenses = int(wage) * int(mortgage) / 100 * 12
accumulation = (int(wage) * 12 + int(wage) * int(premium)) - (mortgage_expenses + int(wage) * 12 * int(spending) / 100 + int(wage) * int(premium) * 0.5)
print('Вывод: На ипотеку было потрачено:', mortgage_expenses, ' рублей. Было накоплено:', accumulation, 'рублей.')
# Out:
# Введите заработанную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# Вывод: На ипотеку было потрачено: 360000.0  рублей. Было накоплено: 340000.0 рублей.
